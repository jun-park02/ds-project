# %%
import pandas as pd
import re

df = pd.read_csv("아파트_매매_실거래가격지수_20260525142438.csv")
df.head()
# Out:
#    행정구역별(1)  행정구역별(2)               2006.01               2006.02  \
# 0  행정구역별(1)  행정구역별(2)  지수 (2017.11 = 100.0)  지수 (2017.11 = 100.0)
# 1        전국        소계                  60.0                  60.5
# 2       수도권        소계                  62.8                  63.7
# 3        지방        소계                  57.7                  57.6
# 4        서울        서울                  58.5                  59.4
#
#                 2006.03               2006.04               2006.05  \
# 0  지수 (2017.11 = 100.0)  지수 (2017.11 = 100.0)  지수 (2017.11 = 100.0)
# 1                  61.2                  61.7                  62.0
# 2                  64.8                  65.6                  66.2
# 3                  57.7                  57.7                  57.7
# 4                  60.9                  61.6                  61.9
#
#                 2006.06               2006.07               2006.08  ...  \
# 0  지수 (2017.11 = 100.0)  지수 (2017.11 = 100.0)  지수 (2017.11 = 100.0)  ...
# ...
